# %% [markdown]
# # OMITIR SIEMPRE PRIMERA COLUMNA

# %%
import pandas as pd

def safe_read_csv(path):
    """Read CSV robustly: tries common encodings/separators and skips malformed rows."""
    last_error = None
    for encoding in ("utf-8", "utf-8-sig", "latin1"):
        for sep in (",", ";"):
            try:
                return pd.read_csv(path, encoding=encoding, sep=sep, engine="python", on_bad_lines="skip")
            except Exception as err:
                last_error = err
    raise last_error

# %%
print("Este es el df1 -> PerdidaDeBecas.csv")


df1 = safe_read_csv("datos_raw/personas/PerdidaDeBecas.csv")
df1.head()
# Convocatoria,region,Descripcion,Resolucion_Ret_Beca,Fec_Resolucion_Ret_Beca,Fec_Postulacion,TipoInstitucion,InstitucionEducativa,InstitucionSede,CarreraDescripcion,Genero,FECHA_HORA
# Out:
# Este es el df1 -> PerdidaDeBecas.csv
#    1                  Beca Perú (Lima - Callao) 2014-02       LIMA  \
# 0  2                        CREDITO CONTINUIDAD 2020          LIMA
# 1  3            Beca Presidente de la República 2017        ESPAÑA
# 2  4            Beca de Continuidad de Estudios 2020         CUSCO
# 3  5  Beca de Permanencia de Estudios - Nacional 201...   AREQUIPA
# 4  6                 Presidente de la República 2013-04  ARGENTINA
#
#   Becarios que abandonaron los estudios (No recibieron subvencion)  \
# 0                            Becarios con suspension
# 1                          Becarios declarados nulos
# 2                          Becarios declarados nulos
# 3                          Becarios declarados nulos
# 4                          Becarios declarados nulos
#
#    RESOLUCION JEFATURAL  2015-08  2014-06  Instituto de Educación Superior  \
# 0  RESOLUCION JEFATURAL  2021-05  2020-07                      Universidad
# ...

# %%
print("Este es el df2 -> NotaPromedioDelPostulantePorRegion.csv")


df2 = safe_read_csv("datos_raw/personas/NotaPromedioDelPostulantePorRegion.csv")
df2.head()

# Region, Promedio, Modalidad, Anio_Convocatoria, TipoInstitucion, InstitucionEducativa, Semestre, FECHA_HORA
# Out:
# Este es el df2 -> NotaPromedioDelPostulantePorRegion.csv
#    1  CUBA   4  000000 Modalidad Pregrado Internacional  2013  \
# 0  2  LIMA  14  500000                         Albergue  2015
# 1  3  LIMA  12       0        Beca Excelencia Academica  2014
# 2  4  LIMA  13       0                        Beca Peru  2013
# 3  5  LIMA  11       0                        Beca Peru  2013
# 4  6  LIMA  15       0            Beca Vocacion Maestro  2014
#
#                         Unnamed: 6                                 Unnamed: 7  \
# 0                      Universidad  UNIVERSIDAD PRIVADA SAN IGNACIO DE LOYOLA
# 1                      Universidad   PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU
# 2  Instituto de Educación Superior       IES PRIVADO FREDERICK WINSLOW TAYLOR
# 3  Instituto de Educación Superior       IES PRIVADO FREDERICK WINSLOW TAYLOR
# 4                      Universidad   PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU
#
#     2013-I  14/04/2026 14:01:21
# ...

# %%
print("Este es el df3 -> EstadosDelBecario.csv")

df3 = safe_read_csv("datos_raw/personas/EstadosDelBecario.csv")
df3.head()

# Estado, Condicion, Causal, FECHA_HORA
# Out:
# Este es el df3 -> EstadosDelBecario.csv
#    1    ACTIVO     REGULAR                            SIN OBSERVACION  \
# 0  2    ACTIVO     REGULAR  BECARIOS OBSERVADOS Y/O EN REGULARIZACION
# 1  3    ACTIVO  SUSPENDIDO                    BECARIOS CON SUSPENSION
# 2  4    ACTIVO   OBSERVADO  BECARIOS OBSERVADOS Y/O EN REGULARIZACION
# 3  5    ACTIVO  EX-BECARIO                  BECARIO EGRESADO APROBADO
# 4  6  INACTIVO     REGULAR                   BECARIOS QUE RENUNCIARON
#
#    14/04/2026 14:01:22
# 0  14/04/2026 14:01:22
# 1  14/04/2026 14:01:22
# 2  14/04/2026 14:01:22
# 3  14/04/2026 14:01:22
# 4  14/04/2026 14:01:22

# %%
print("Este es el df4 -> Credito18Postulacion.csv")

df4 = safe_read_csv("datos_raw/personas/Credito18Postulacion.csv")
df4.head()

# Convocatoria, TipoInstitucion, InstitucionEducativa, InstitucionSede, Descripcion, EstadoCredito18, Periodo_Postulacion, Period_registro_postulac, Period_anulacion, UbigeoLocalidad, FECHA_HORA
# Out:
# Este es el df4 -> Credito18Postulacion.csv
#    1  1era. convocatoria  Universidad  \
# 0  2   2da. convocatoria  Universidad
# 1  3   2da. convocatoria  Universidad
# 2  4  1era. convocatoria  Universidad
# 3  5   2da. convocatoria  Universidad
# 4  6   2da. convocatoria  Universidad
#
#    PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL  \
# 0  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
# 1  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
# 2  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
# 3  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
# 4  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
#
#        ARQUITECTURA  REGISTRO COMPLETO  2016-01 2016-01.1 Unnamed: 9  \
# 0      ARQUITECTURA  REGISTRO COMPLETO  2016-08   2016-08    2016-08
# 1      ARQUITECTURA  REGISTRO COMPLETO  2016-08   2016-08    2017-01
# 2  INGENIERIA CIVIL  REGISTRO COMPLETO  2016-02   2015-12    2016-02
# ...

# %%
print("Este es el df5 -> Credito18EvaluacionSolicitud.csv")

df5 = safe_read_csv("datos_raw/personas/Credito18EvaluacionSolicitud.csv")
df5.head()
# Convocatoria,TipoInstitucion,InstitucionEducativa,InstitucionSede,Descripcion,EstadoCredito18,Periodo_Postulacion,Period_registro_postulac,Period_anulacion,UbigeoLocalidad,FECHA_HORA
# Out:
# Este es el df5 -> Credito18EvaluacionSolicitud.csv
#    1   2da. convocatoria  Universidad  \
# 0  2  1era. convocatoria  Universidad
# 1  3   2da. convocatoria  Universidad
# 2  4   2da. convocatoria  Universidad
# 3  5  1era. convocatoria  Universidad
# 4  6  1era. convocatoria  Universidad
#
#    PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL  \
# 0  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
# 1  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
# 2  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
# 3  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
# 4  PONTIFICIA UNIVERSIDAD CATOLICA DEL PERU  SEDE SAN MIGUEL
#
#        ARQUITECTURA       REGISTRO COMPLETO  2016-08 2016-08.1  2017-01  \
# 0      ARQUITECTURA       REGISTRO COMPLETO  2016-01   2016-01      NaN
# 1      ARQUITECTURA       REGISTRO COMPLETO  2016-08   2016-08  2016-08
# 2  INGENIERIA CIVIL  EN PROCESO DE REGISTRO      NaN   2016-08      NaN
# ...

# %%
print("Este es el df6 -> Credito18DatosSolicitante.csv")

df6 = safe_read_csv("datos_raw/personas/Credito18DatosSolicitante.csv")
df6.head()
#Id_Persona,Convocatoria,EstudianteTipo,FamiliarTipo,TieneTelefonoFijo,TieneTelefonoCelular,TieneEmail,Ingresos_Mensuales,Gastos_Mensuales,Fecha_Registro,TieneFichaSocioeconomica,Genero,NacimientoUbigeo,FECHA_HORA
# Out:
# Este es el df6 -> Credito18DatosSolicitante.csv
#    1  PD1zq  1era. convocatoria Unnamed: 3  PADRE     Tiene   Tiene.1  \
# 0  2   Rqm8                 NaN        NaN  PADRE  No Tiene  No tiene
# 1  3  QDWGz  1era. convocatoria        NaN  PADRE  No Tiene  No tiene
# 2  4  V0A3m  1era. convocatoria        NaN  PADRE     Tiene     Tiene
# 3  5  K2pQv  1era. convocatoria        NaN  PADRE  No Tiene     Tiene
# 4  6  7bjEe  1era. convocatoria        NaN  PADRE     Tiene     Tiene
#
#     Tiene.2     200 200.1  2015-11 Tiene.3   FEMENINO  \
# 0  No Tiene  1650.0   NaN  2020-03   Tiene  MASCULINO
# 1  No Tiene  1800.0   NaN  2021-08   Tiene   FEMENINO
# 2      sdsd  3000.0  2000  2015-11   Tiene        NaN
# 3  No Tiene  2400.0  2300  2015-12   Tiene  MASCULINO
# 4  No Tiene  1700.0  1500  2015-12   Tiene        NaN
#
#                        CALANA  14/04/2026 14:01:19
# 0  CARMEN DE LA LEGUA REYNOSO  14/04/2026 14:01:19
# 1                 JESUS MARIA  14/04/2026 14:01:19
# ...

# %%
print("Este es el df7 -> NotasDeBecarios_Top200.csv")
df7 = safe_read_csv("datos_raw/personas/becados/NotasDeBecarios_Top200.csv")
df7.head()

# Postulacion, Semestre, Ciclo, Nota(enteros), Nota(decimales_que_se_suman _a_enteros), FECHA_HORA
# Out:
# Este es el df7 -> NotasDeBecarios_Top200.csv
#    1  LMqR  2012-II      PRIMER CICLO  16  43  14/04/2026 15:27:04
# 0  2  pNgl  2012-II  CICLO NIVELACION  13  80  14/04/2026 15:27:04
# 1  3  pNgl   2013-I      PRIMER CICLO  13  31  14/04/2026 15:27:04
# 2  4  ndZ7  2012-II      PRIMER CICLO  15  37  14/04/2026 15:27:04
# 3  5  ndZ7   2013-I     SEGUNDO CICLO  14  51  14/04/2026 15:27:04
# 4  6  ndZ7  2013-II      TERCER CICLO  15  33  14/04/2026 15:27:04

# %%
print("Este es el df8 -> Convocatorias.csv")
df8 = safe_read_csv("datos_raw/becas/Convocatorias.csv")
df8.head()

#Id_Convocatoria, Codigo_anual_convocat, Descripcion, Modalidad_Descripcion, Programa_Descripcion, Becas_ofertadas, TipoLimiteEdad, Fec_LimiteEdad, Fec_Ini_Inscripcion, Fec_Fin_Inscripcion, Fec_Ini_Evaluacion, Fec_Fin_Evaluacion, Fec_Ini_Ejecucion, Fec_Fin_Ejecucion, RangoEdadInicio, RangoEdadFin, RJ_Aprobacion, FECHA_HORA
# Out:
# Este es el df8 -> Convocatorias.csv
#      1  23  2013-02  \
# 0  2.0   3  2012-01
# 1  3.0  10  2013-01
# 2  4.0  12  2012-02
# 3  5.0  13  2012-01
# 4  6.0  16  2012
#
#   Beca Excelencia para estudios de Postgrado en el Extranjero  \
# 0                                          Beca Perú
# 1                       Beca 18 Internacional - Cuba
# 2                    Beca 18 FFAA (2da Convocatoria)
# 3                                      Beca 18 VRAEM
# 4                        Beca 18 Modalidad Ordinaria
#
#   Beca Generación del Bicentenario (anteriormente denominada Beca Presidente de la República)  \
# 0                                          Beca Peru
# 1                   Modalidad Pregrado Internacional
# 2                                   Licenciados FFAA
# 3                                              VRAEM
# 4                                Modalidad Ordinaria
#
#   Becas Postgrado Extranjero     400  Unnamed: 7  31/12/2013  25/11/2012  \
# ...

# %%
print("Este es el df9 -> ConvocatoriaPorCarreraSede_Top200.csv")


df9 = safe_read_csv("datos_raw/becas/ConvocatoriaPorCarreraSede_Top200.csv")
df9.head()

# Id_Convocatoria, ConvocatoriaDescripcion, PaisOrigen, NivelEducativo, TipoInstitucion, SedeNombre, Nombre, CarreraDescripcion, Resolucion_Autoriza, TipoDeGestion, Abreviatura, Region,DireccionWeb, Representante, Telefono, Ruc, Email, FECHA_HORA
# Out:
# Este es el df9 -> ConvocatoriaPorCarreraSede_Top200.csv
#      1                                                139  \
# 2  140  Beca Alianza del Pacífico (Peruanos en el extr...
# 3  140  Beca Alianza del Pacífico (Peruanos en el extr...
# 4  389                Crédito Talento - Convocatoria 2023
# 5  389                Crédito Talento - Convocatoria 2023
# 6  389                Crédito Talento - Convocatoria 2023
#
#   Beca Alianza del Pacífico (extranjeros en el Perú)                   PERU  \
# 2                                             MEXICO  Carrera Universitaria
# 3                                             MEXICO  Carrera Universitaria
# 4                                               PERU  Carrera Universitaria
# 5                                               PERU  Carrera Universitaria
# 6                                               PERU  Carrera Universitaria
#
#   Carrera Universitaria                  Universidad  \
# ...

# %% [markdown]
# 1.- Items a recomendar
# CSVs: ConvocatoriaPorCarreraSede_Top200.csv (df9) y Convocatorias.csv (df8).
#
# Explicación: df9 detalla carreras e instituciones, mientras df8 aporta límites de edad y tipo de beca. Juntos forman el catálogo exacto de opciones a evaluar.
#
# 2.- Usuario
# CSVs: Credito18DatosSolicitante.csv (df6) y Credito18Postulacion.csv (df4).
#
# Explicación: df6 define el perfil socioeconómico (ingresos, ubicación), mientras df4 muestra la intención académica (carrera/universidad). Son los datos de entrada para tu motor concurrente.
#
# 3.- El historial de quién ganó qué
# Como los datos están anonimizados para proteger la identidad, tienes dos opciones válidas para implementar el cruce:
#
# Opción A (Cruce Directo por Reglas):
#
# CSVs: df6 (Usuario) + df8 y df9 (Becas).
#
# Explicación: Las goroutines cruzan directamente los ingresos y ubicación del estudiante (df6) con los requisitos de la beca (df8, df9). No depende del historial pasado.
#
# Opción B (Historial de Éxito / Predictivo):
#
# CSVs: df4 (Postulaciones) + df7 (NotasDeBecarios_Top200.csv).
#
# Explicación: Usas df4 para ver a dónde postularon y cruzas con df7 porque solo los ganadores reales generan registros de notas, sirviendo como tu historial de éxito.

# %% [markdown]
# <!-- 1.- Items a recomendar
# CSVs: ConvocatoriaPorCarreraSede_Top200.csv (df9) y Convocatorias.csv (df8).
#
# Explicación: df9 detalla carreras e instituciones, mientras df8 aporta límites de edad y tipo de beca. Juntos forman el catálogo exacto de opciones a evaluar.
#
# 2.- Usuario
# CSVs: Credito18DatosSolicitante.csv (df6) y Credito18Postulacion.csv (df4).
#
# Explicación: df6 define el perfil socioeconómico (ingresos, ubicación), mientras df4 muestra la intención académica (carrera/universidad). Son los datos de entrada para tu motor concurrente.
#
# 3.- El historial de quién ganó qué
# Como los datos están anonimizados para proteger la identidad, tienes dos opciones válidas para implementar el cruce:
#
# Opción A (Cruce Directo por Reglas):
#
# CSVs: df6 (Usuario) + df8 y df9 (Becas).
#
# Explicación: Las goroutines cruzan directamente los ingresos y ubicación del estudiante (df6) con los requisitos de la beca (df8, df9). No depende del historial pasado.
#
# Opción B (Historial de Éxito / Predictivo):
#
# CSVs: df4 (Postulaciones) + df7 (NotasDeBecarios_Top200.csv).
#
# Explicación: Usas df4 para ver a dónde postularon y cruzas con df7 porque solo los ganadores reales generan registros de notas, sirviendo como tu historial de éxito. -->

# %% [markdown]
# Lo que tengo planeado:
# 1.- Multiplicar los datos necesarios.
#
# 2.- Cambiar nombre las columnas de los csv necesarios.
#
# 3.- Hacer limpieza de datos (valores nulos, eliminar columnas innecesarias)
#
# CON ESO YA ESTARÍAMOS PARA LA PC
